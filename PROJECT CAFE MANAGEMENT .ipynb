# %%
from tkinter import *#for GUI
import random
import time
from datetime import date
import tkinter.messagebox
import os
import tempfile
import mysql.connector

root=Tk()
root.geometry("1350x750+0+0")
root.title("Cafe 10 Management System")
root.config(bg='black')
lis=[]


#---------------------VARIABLES-----------------------------
#DRINK INITIALIZERS


ColdDrink=IntVar()
ColdCoffee=IntVar()
Tea=IntVar()
Coffee=IntVar()
MinuteMaid=IntVar()
IceTea=IntVar()

#Snacks Initializers


Pizza=IntVar()
Patties=IntVar()
Samosa=IntVar()
Sandwhich=IntVar()
Frenchfries=IntVar()
StuffKulcha=IntVar()



#MainCourse Initializers
CholeRice=IntVar()
thali=IntVar()
RajmaRice=IntVar()
Dosa=IntVar()
CholeBhature=IntVar()
Omelette=IntVar()


#Deserts Initializers
IceCream=IntVar()
Pastry=IntVar()
Shake=IntVar()
GulabJamun=IntVar()
Rasgulla=IntVar()
ChocoLavaCake=IntVar()


E_ColdDrink=StringVar()
E_ColdCoffee=StringVar()
E_Tea=StringVar()
E_Coffee=StringVar()
E_MinuteMaid=StringVar()
E_IceTea=StringVar()




E_Pizza=StringVar()
E_Patties=StringVar()
E_Samosa=StringVar()
E_Sandwhich=StringVar()
E_Frenchfries=StringVar()
E_StuffKulcha=StringVar()




E_CholeRice=StringVar()
E_thali=StringVar()
E_RajmaRice=StringVar()
E_Dosa=StringVar()
E_CholeBhature=StringVar()
E_Omelette=StringVar()



E_IceCream=StringVar()
E_Pastry=StringVar()
E_Shake=StringVar()
E_GulabJamun=StringVar()
E_Rasgulla=StringVar()
E_ChocoLavaCake=StringVar()



DateofOrder=StringVar()
Receipt_Ref=StringVar()

#----------------------------SETS--------------------------------------------
ColdDrink.set("0")
ColdCoffee.set("0")
Tea.set("0")
Coffee.set("0")
MinuteMaid.set("0")
IceTea.set("0")

Pizza.set("0")
Patties.set("0")
Samosa.set("0")
Sandwhich.set("0")
Frenchfries.set("0")
StuffKulcha.set("0")

CholeRice.set("0")
thali.set("0")
RajmaRice.set("0")
Dosa.set("0")
CholeBhature.set("0")
Omelette.set("0")


IceCream.set("0")
Pastry.set("0")
Shake.set("0")
GulabJamun.set("0")
Rasgulla.set("0")
ChocoLavaCake.set("0")


E_ColdDrink.set("0")
E_ColdCoffee.set("0")
E_Tea.set("0")
E_Coffee.set("0")
E_MinuteMaid.set("0")
E_IceTea.set("0")


E_Pizza.set("0")
E_Patties.set("0")
E_Samosa.set("0")
E_Sandwhich.set("0")
E_Frenchfries.set("0")
E_StuffKulcha.set("0")


E_CholeRice.set("0")
E_thali.set("0")
E_RajmaRice.set("0")
E_Dosa.set("0")
E_CholeBhature.set("0")
E_Omelette.set("0")


E_IceCream.set("0")
E_Pastry.set("0")
E_Shake.set("0")
E_GulabJamun.set("0")
E_Rasgulla.set("0")
E_ChocoLavaCake.set("0")


def chk():
    if ColdDrink.get()==1:
        txtColdDrink.config(state=NORMAL)
    elif ColdDrink.get()==0:
        txtColdDrink.config(state=DISABLED)
        E_ColdDrink.set("0")
    if ColdCoffee.get()==1:
        txtColdCoffee.config(state=NORMAL)
    elif ColdCoffee.get()==0:
        txtColdCoffee.config(state=DISABLED)
        E_ColdCoffee.set("0")
    if Tea.get()==1:
        txtTea.config(state=NORMAL)
    elif Tea.get()==0:
        txtTea.config(state=DISABLED)
        E_Tea.set("0")
    if MinuteMaid.get()==1:
        txtMinuteMaid.config(state=NORMAL)
    elif MinuteMaid.get()==0:
        txtMinuteMaid.config(state=DISABLED)
        E_MinuteMaid.set("0")
    if Coffee.get()==1:
        txtCoffee.config(state=NORMAL)
    elif Coffee.get()==0:
        txtCoffee.config(state=DISABLED)
        E_Coffee.set("0")
    if IceTea.get()==1:
        txtIceTea.config(state=NORMAL)
    elif IceTea.get()==0:
        txtIceTea.config(state=DISABLED)
        E_IceTea.set("0")
        
        
        
        
    if Pizza.get()==1:
        txtPizza.config(state=NORMAL)
    elif Pizza.get()==0:
        txtPizza.config(state=DISABLED)
        E_Pizza.set("0")
    if Patties.get()==1:
        txtPatties.config(state=NORMAL)
    elif Patties.get()==0:
        txtPatties.config(state=DISABLED)
        E_Patties.set("0")
    if Samosa.get()==1:
        txtSamosa.config(state=NORMAL)
    elif Samosa.get()==0:
        txtSamosa.config(state=DISABLED)
        E_Samosa.set("0")
    if Sandwhich.get()==1:
        txtSandwhich.config(state=NORMAL)
    elif Sandwhich.get()==0:
        txtSandwhich.config(state=DISABLED)
        E_Sandwhich.set("0")
    if Frenchfries.get()==1:
        txtFrenchfries.config(state=NORMAL)
    elif Frenchfries.get()==0:
        txtFrenchfries.config(state=DISABLED)
        E_Frenchfries.set("0")
    if StuffKulcha.get()==1:
        txtStuffKulcha.config(state=NORMAL)
    elif StuffKulcha.get()==0:
        txtStuffKulcha.config(state=DISABLED)
        E_StuffKulcha.set("0")  
        
        
    if CholeRice.get()==1:
        txtCholeRice.config(state=NORMAL)
    elif CholeRice.get()==0:
        txtCholeRice.config(state=DISABLED)
        E_CholeRice.set("0")
    if thali.get()==1:
        txtthali.config(state=NORMAL)
    elif thali.get()==0:
        txtthali.config(state=DISABLED)
        E_thali.set("0")
    if RajmaRice.get()==1:
        txtRajmaRice.config(state=NORMAL)
    elif RajmaRice.get()==0:
        txtRajmaRice.config(state=DISABLED)
        E_RajmaRice.set("0")
    if Dosa.get()==1:
        txtDosa.config(state=NORMAL)
    elif Dosa.get()==0:
        txtDosa.config(state=DISABLED)
        E_Dosa.set("0")
    if CholeBhature.get()==1:
        txtCholeBhature.config(state=NORMAL)
    elif CholeBhature.get()==0:
        txtCholeBhature.config(state=DISABLED)
        E_CholeBhature.set("0")
    if Omelette.get()==1:
        txtOmelette.config(state=NORMAL)
    elif Omelette.get()==0:
        txtOmelette.config(state=DISABLED)
        E_Omelette.set("0") 
    
    
    if IceCream.get()==1:
        txtIceCream.config(state=NORMAL)
    elif IceCream.get()==0:
        txtIceCream.config(state=DISABLED)
        E_IceCream.set("0")
    if Shake.get()==1:
        txtShake.config(state=NORMAL)
    elif Shake.get()==0:
        txtShake.config(state=DISABLED)
        E_Shake.set("0")
    if Rasgulla.get()==1:
        txtRasgulla.config(state=NORMAL)
    elif Rasgulla.get()==0:
        txtRasgulla.config(state=DISABLED)
        E_Rasgulla.set("0")
    if ChocoLavaCake.get()==1:
        txtChocoLavaCake.config(state=NORMAL)
    elif ChocoLavaCake.get()==0:
        txtChocoLavaCake.config(state=DISABLED)
        E_ChocoLavaCake.set("0")
    if GulabJamun.get()==1:
        txtGulabJamun.config(state=NORMAL)
    elif GulabJamun.get()==0:
        txtGulabJamun.config(state=DISABLED)
        E_GulabJamun.set("0")
    if Pastry.get()==1:
        txtPastry.config(state=NORMAL)
    elif Pastry.get()==0:
        txtPastry.config(state=DISABLED)
        E_Pastry.set("0") 
        


#----------------------------------------------------------------------------------

Tops=Frame(root,width=1350,height=100,bd=14,relief="raise")
Tops.pack(side=TOP)
f1=Frame(root,width=900,height=500,bd=8,relief="raise")
f1.pack(side=LEFT)
f2=Frame(root,width=1350,height=500,bd=8,relief="raise")
f2.pack(side=RIGHT)

f1a=Frame(f1,width=900,height=250,bd=8,relief="raise")
f1a.pack(side=TOP)
f2a=Frame(f1,width=900,height=250,bd=6,relief="raise")
f2a.pack(side=BOTTOM)


f1aa=Frame(f1a,width=450,height=250,bd=8,relief="raise")
f1aa.pack(side=LEFT)
f1ab=Frame(f1a,width=450,height=250,bd=8,relief="raise")
f1ab.pack(side=RIGHT)


f2aa=Frame(f2a,width=450,height=250,bd=8,relief="raise")
f2aa.pack(side=LEFT)
f2ab=Frame(f2a,width=450,height=250,bd=8,relief="raise")
f2ab.pack(side=RIGHT)



ft2 = Frame(f2,width = 600,height =500,bd=12,relief="raise")
ft2.pack(side=TOP)
fb2 = Frame(f2,width = 600,height =65,bd=16,relief="raise")
fb2.pack(side=BOTTOM)

photo = PhotoImage(file="logocafe.png")
middleframe=Label(root,image=photo)
middleframe.pack(expand='yes')



photo2 = PhotoImage(file="coffee.png")
middleframe1=Label(root,image=photo2)
middleframe1.pack(expand='yes')







topinfo=Label(Tops,text="CAFE 10 MANAGEMENT SYSTEM",font=("Arial",60,"bold"))
topinfo.grid(row=0)
#---------------------------------DRINKS---------------------------------------------




#CheckButtons
C_ColdDrink =Checkbutton(f1aa,text="ColdDrink \t(20)",variable=ColdDrink,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_ColdCoffee=Checkbutton(f1aa,text="ColdCoffee \t(20)",variable=ColdCoffee,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Tea       =Checkbutton(f1aa,text="Tea \t\t(10)",variable=Tea,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Coffee    =Checkbutton(f1aa,text="Coffee \t\t(10)",variable=Coffee,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_MinuteMaid=Checkbutton(f1aa,text="MinuteMaid \t(20)",variable=MinuteMaid,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_IceTea    =Checkbutton(f1aa,text="IceTea\t\t(20)",variable=IceTea,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)



C_ColdDrink.grid(row=0,sticky=W,)
C_ColdCoffee.grid(row=1,sticky=W)
C_Tea.grid(row=2,sticky=W)
C_Coffee.grid(row=3,sticky=W)
C_MinuteMaid.grid(row=4,sticky=W)
C_IceTea.grid(row=5,sticky=W)



#--------------------------------Snacks-----------------------------



#CheckButtons
C_Pizza=Checkbutton(f1ab,text="Pizza \t\t(50)",variable=Pizza,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Patties=Checkbutton(f1ab,text="Patties \t\t(15)",variable=Patties,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Samosa=Checkbutton(f1ab,text="Samosa \t\t(10)",variable=Samosa,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Sandwhich=Checkbutton(f1ab,text="Sandwhich \t(20)",variable=Sandwhich,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Frenchfries=Checkbutton(f1ab,text="Frenchfries \t(40)",variable=Frenchfries,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_StuffKulcha=Checkbutton(f1ab,text="StuffKulcha \t(40)",variable=StuffKulcha,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)



C_Pizza.grid(row=0,sticky=W,)
C_Patties.grid(row=1,sticky=W)
C_Samosa.grid(row=2,sticky=W)
C_Sandwhich.grid(row=3,sticky=W)
C_Frenchfries.grid(row=4,sticky=W)
C_StuffKulcha.grid(row=5,sticky=W)



#--------------------------------------MAIN COURSE---------------------------





#CheckButtons
C_CholeRice=Checkbutton(f2aa,text="CholeRice \t(60)",variable=CholeRice,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_thali=Checkbutton(f2aa,text="thali \t\t(90)",variable=thali,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_RajmaRice=Checkbutton(f2aa,text="RajmaRice \t(60)",variable=RajmaRice,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Dosa=Checkbutton(f2aa,text="Dosa \t\t(70)",variable=Dosa,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_CholeBhature=Checkbutton(f2aa,text="CholeBhature \t(50)",variable=CholeBhature,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Omelette=Checkbutton(f2aa,text="Omelette \t\t(40)",variable=Omelette,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)



C_CholeRice.grid(row=0,sticky=W,)
C_thali.grid(row=1,sticky=W)
C_RajmaRice.grid(row=2,sticky=W)
C_Dosa.grid(row=3,sticky=W)
C_CholeBhature.grid(row=4,sticky=W)
C_Omelette.grid(row=5,sticky=W)





#--------------------------------------DESERTS---------------------------




#CheckButtons
C_IceCream=Checkbutton(f2ab,text="IceCream \t(15)",variable=IceCream,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Pastry=Checkbutton(f2ab,text="Pastry \t\t(25)",variable=Pastry,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Shake=Checkbutton(f2ab,text="Shake \t\t(40)",variable=Shake,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_GulabJamun=Checkbutton(f2ab,text="GulabJamun \t(20)",variable=GulabJamun,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_Rasgulla=Checkbutton(f2ab,text="Rasgulla \t\t(20)",variable=Rasgulla,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)
C_ChocoLavaCake=Checkbutton(f2ab,text="ChocoLavaCake \t(50)",variable=ChocoLavaCake,onvalue=1,offvalue=0,bd=8,font=("Arial",12,"bold"),command=chk)



C_IceCream.grid(row=0,sticky=W,)
C_Pastry.grid(row=1,sticky=W)
C_Shake.grid(row=2,sticky=W)
C_GulabJamun.grid(row=3,sticky=W)
C_Rasgulla.grid(row=4,sticky=W)
C_ChocoLavaCake.grid(row=5,sticky=W)


#-------------------------ENTRIES--------------------------------
#-------------------------DRINKS---------------------------------

txtColdDrink=Entry(f1aa,textvariable=E_ColdDrink,width=6,justify='left',state=DISABLED)
txtColdDrink.grid(row=0,column=1)
txtColdCoffee=Entry(f1aa,textvariable=E_ColdCoffee,width=6,justify='left',state=DISABLED)
txtColdCoffee.grid(row=1,column=1)
txtTea=Entry(f1aa,textvariable=E_Tea,width=6,justify='left',state=DISABLED)
txtTea.grid(row=2,column=1)
txtCoffee=Entry(f1aa,textvariable=E_Coffee,width=6,justify='left',state=DISABLED)
txtCoffee.grid(row=3,column=1)
txtMinuteMaid=Entry(f1aa,textvariable=E_MinuteMaid,width=6,justify='left',state=DISABLED)
txtMinuteMaid.grid(row=4,column=1)
txtIceTea=Entry(f1aa,textvariable=E_IceTea,width=6,justify='left',state=DISABLED)
txtIceTea.grid(row=5,column=1)



#--------------------------SNACKS--------------------------

txtPizza=Entry(f1ab,textvariable=E_Pizza,width=6,justify='left',state=DISABLED)
txtPizza.grid(row=0,column=1)
txtPatties=Entry(f1ab,textvariable=E_Patties,width=6,justify='left',state=DISABLED)
txtPatties.grid(row=1,column=1)
txtSamosa=Entry(f1ab,textvariable=E_Samosa,width=6,justify='left',state=DISABLED)
txtSamosa.grid(row=2,column=1)
txtSandwhich=Entry(f1ab,textvariable=E_Sandwhich,width=6,justify='left',state=DISABLED)
txtSandwhich.grid(row=3,column=1)
txtFrenchfries=Entry(f1ab,textvariable=E_Frenchfries,width=6,justify='left',state=DISABLED)
txtFrenchfries.grid(row=4,column=1)
txtStuffKulcha=Entry(f1ab,textvariable=E_StuffKulcha,width=6,justify='left',state=DISABLED)
txtStuffKulcha.grid(row=5,column=1)


#-------------------MAINCOURSE------------------------

txtCholeRice=Entry(f2aa,textvariable=E_CholeRice,width=6,justify='left',state=DISABLED)
txtCholeRice.grid(row=0,column=1)
txtthali=Entry(f2aa,textvariable=E_thali,width=6,justify='left',state=DISABLED)
txtthali.grid(row=1,column=1)
txtRajmaRice=Entry(f2aa,textvariable=E_RajmaRice,width=6,justify='left',state=DISABLED)
txtRajmaRice.grid(row=2,column=1)
txtDosa=Entry(f2aa,textvariable=E_Dosa,width=6,justify='left',state=DISABLED)
txtDosa.grid(row=3,column=1)
txtCholeBhature=Entry(f2aa,textvariable=E_CholeBhature,width=6,justify='left',state=DISABLED)
txtCholeBhature.grid(row=4,column=1)
txtOmelette=Entry(f2aa,textvariable=E_Omelette,width=6,justify='left',state=DISABLED)
txtOmelette.grid(row=5,column=1)



#-------------------------DESERTS-------------------------------

txtIceCream=Entry(f2ab,textvariable=E_IceCream,width=6,justify='left',state=DISABLED)
txtIceCream.grid(row=0,column=1)
txtPastry=Entry(f2ab,textvariable=E_Pastry,width=6,justify='left',state=DISABLED)
txtPastry.grid(row=1,column=1)
txtShake=Entry(f2ab,textvariable=E_Shake,width=6,justify='left',state=DISABLED)
txtShake.grid(row=2,column=1)
txtGulabJamun=Entry(f2ab,textvariable=E_GulabJamun,width=6,justify='left',state=DISABLED)
txtGulabJamun.grid(row=3,column=1)
txtRasgulla=Entry(f2ab,textvariable=E_Rasgulla,width=6,justify='left',state=DISABLED)
txtRasgulla.grid(row=4,column=1)
txtChocoLavaCake=Entry(f2ab,textvariable=E_ChocoLavaCake,width=6,justify='left',state=DISABLED)
txtChocoLavaCake.grid(row=5,column=1)

#------------------------------------------------------------





#---------------------------------cost items information---------------------------------------------
 


#---------------------------------FUNCTIONS TO BE MADE---------------------------------------------
def qExit():
    qExit= tkinter.messagebox.askyesno("Quit System","Do you want to exit ?")
    if qExit>0:
        root.destroy()
        return    
    
    
    
def Reset():
    txtReceipt.delete("1.0",END)

    ColdDrink.set("0")
    ColdCoffee.set("0")
    Tea.set("0")
    Coffee.set("0")
    MinuteMaid.set("0")
    IceTea.set("0")
    
    
    Pizza.set("0")
    Patties.set("0")
    Samosa.set("0")
    Sandwhich.set("0")
    Frenchfries.set("0")
    StuffKulcha.set("0")
    
    
    CholeRice.set("0")
    thali.set("0")
    RajmaRice.set("0")
    Dosa.set("0")
    CholeBhature.set("0")
    Omelette.set("0")
    
    
    IceCream.set("0")
    Pastry.set("0")
    Shake.set("0")
    GulabJamun.set("0")
    Rasgulla.set("0")
    ChocoLavaCake.set("0")


    
    E_ColdDrink.set("0")
    E_ColdCoffee.set("0")
    E_Tea.set("0")
    E_Coffee.set("0")
    E_MinuteMaid.set("0")
    E_IceTea.set("0")


    E_Pizza.set("0")
    E_Patties.set("0")
    E_Samosa.set("0")
    E_Sandwhich.set("0")
    E_Frenchfries.set("0")
    E_StuffKulcha.set("0")


    E_CholeRice.set("0")
    E_thali.set("0")
    E_RajmaRice.set("0")
    E_Dosa.set("0")
    E_CholeBhature.set("0")
    E_Omelette.set("0")


    E_IceCream.set("0")
    E_Pastry.set("0")
    E_Shake.set("0")
    E_GulabJamun.set("0")
    E_Rasgulla.set("0")
    E_ChocoLavaCake.set("0")

    
    txtColdDrink.configure(state= DISABLED)
    txtColdCoffee.configure(state= DISABLED)
    txtTea.configure(state= DISABLED)
    txtCoffee.configure(state= DISABLED)
    txtMinuteMaid.configure(state= DISABLED)
    txtIceTea.configure(state= DISABLED)
    
    
    txtPizza.configure(state= DISABLED)
    txtPatties.configure(state= DISABLED)
    txtSamosa.configure(state= DISABLED)
    txtSandwhich.configure(state= DISABLED)
    txtFrenchfries.configure(state= DISABLED)
    txtStuffKulcha.configure(state= DISABLED)
    
    
    txtCholeRice.configure(state= DISABLED)
    txtthali.configure(state= DISABLED)
    txtRajmaRice.configure(state= DISABLED)
    txtDosa.configure(state= DISABLED)
    txtCholeBhature.configure(state= DISABLED)
    txtOmelette.configure(state= DISABLED)
    
    
    txtIceCream.configure(state= DISABLED)
    txtPastry.configure(state= DISABLED)
    txtShake.configure(state= DISABLED)
    txtGulabJamun.configure(state= DISABLED)
    txtRasgulla.configure(state= DISABLED)
    txtChocoLavaCake.configure(state= DISABLED)

    
 #---------------------------------information---------------------------------------------
def CostofItem():
    Item1=float(E_ColdDrink.get())
    Item2=float(E_ColdCoffee.get())
    Item3=float(E_Tea.get())
    Item4=float(E_Coffee.get())
    Item5=float(E_MinuteMaid.get())
    Item6=float(E_IceTea.get())
    
    
    Item7=float(E_Pizza.get())
    Item8=float(E_Patties.get())
    Item9=float(E_Samosa.get())
    Item10=float(E_Sandwhich.get())
    Item11=float(E_Frenchfries.get())
    Item12=float(E_StuffKulcha.get())
    
    
    Item13=float(E_CholeRice.get())
    Item14=float(E_thali.get())
    Item15=float(E_RajmaRice.get())
    Item16=float(E_Dosa.get())
    Item17=float(E_CholeBhature.get())
    Item18=float(E_Omelette.get())
    
    
    Item19=float(E_IceCream.get())
    Item20=float(E_Pastry.get())
    Item21=float(E_Shake.get())
    Item22=float(E_GulabJamun.get())
    Item23=float(E_Rasgulla.get())
    Item24=float(E_ChocoLavaCake.get())

    PriceofDrinks=(Item1 * 20) + (Item2 * 20) + (Item3 * 10)+ (Item4 * 10) + (Item5 * 20) + (Item6 * 20)

    PriceofSnacks= (Item7 * 50) + (Item8 * 15) + (Item9 * 10) + (Item10 * 20) + (Item11 * 40) + (Item12 * 40)
    
    PriceofMainCourse= (Item13 * 60) + (Item14 * 90) + (Item15 * 60) + (Item16 * 70) + (Item17 * 50) + (Item18 * 40)

    PriceofDeserts= (Item19 * 15) + (Item20 * 25) + (Item21 * 40) + (Item22 * 20) + (Item23 * 20) + (Item24 * 50)
    
    
    Total=str(PriceofDrinks + PriceofDeserts  + PriceofMainCourse + PriceofSnacks)
    return Total





lblReceipt = Label(ft2,font=('arial',12,'bold'), text='Receipt',bd=2)
lblReceipt.grid(row=0,column=0)
txtReceipt = Text(ft2, width=60, height=22,bg="white", bd=8, font=('arial', 11, 'bold'))
txtReceipt.grid(row=1,column=0)
 



def Receipt():
    txtReceipt.delete("1.0",END)
    x =  random.randint(10908, 500876)
    randomRef = str(x)
    Receipt_Ref.set("Bill"+ randomRef)
    today=str(date.today())
    DateofOrder.set("Date-"+today)

    txtReceipt.insert(END,'Receipt Ref:\t\t\t'+Receipt_Ref.get() + '\t\t'+ DateofOrder.get()+"\n\n")
    txtReceipt.insert(END,"Items:\t\t\tnumber of Items\t\tCost(INR) \n\n")
    if ColdDrink.get()>0:
        txtReceipt.insert(END,'ColdDrink: \t\t\t'+ E_ColdDrink.get() +"\t\t" +str(float(E_ColdDrink.get())*20)+ "\n")
    if ColdCoffee.get()>0:
        txtReceipt.insert(END,'ColdCoffee: \t\t\t'+ E_ColdCoffee.get() + "\t\t" +str(float(E_ColdCoffee.get())*20)+"\n")
    if Tea.get()>0:
        txtReceipt.insert(END,'Tea: \t\t\t'+ E_Tea.get() +"\t\t" +str(float(E_Tea.get())*10)+ "\n")
    if Coffee.get()>0:
        txtReceipt.insert(END,'Coffee: \t\t\t'+ E_Coffee.get() + "\t\t" +str(float(E_Coffee.get())*10)+"\n")
    if MinuteMaid.get()>0:
        txtReceipt.insert(END,'MinuteMaid: \t\t\t'+ E_MinuteMaid.get() + "\t\t" +str(float(E_MinuteMaid.get())*20)+"\n")
    if IceTea.get()>0:
        txtReceipt.insert(END,'IceTea: \t\t\t'+ E_IceTea.get() + "\t\t" +str(float(E_IceTea.get())*20)+"\n")
    if Pizza.get()>0:
        txtReceipt.insert(END,'Pizza: \t\t\t'+ E_Pizza.get() +"\t\t" +str(float(E_Pizza.get())*50)+ "\n")
    if Patties.get()>0:
        txtReceipt.insert(END,'Patties: \t\t\t'+ E_Patties.get() +"\t\t" +str(float(E_Patties.get())*15)+ "\n")
    if Samosa.get()>0:
        txtReceipt.insert(END,'Samosa: \t\t\t'+ E_Samosa.get() + "\t\t" +str(float(E_Samosa.get())*10)+"\n")
    if Sandwhich.get()>0:
        txtReceipt.insert(END,'Sandwhich: \t\t\t'+ E_Sandwhich.get() +"\t\t" +str(float(E_Sandwhich.get())*20)+ "\n")
    if Frenchfries.get()>0:
        txtReceipt.insert(END,'Frenchfries: \t\t\t'+ E_Frenchfries.get() +"\t\t" +str(float(E_Frenchfries.get())*40)+ "\n")
    if StuffKulcha.get()>0:
        txtReceipt.insert(END,'StuffKulcha: \t\t\t'+ E_StuffKulcha.get() + "\t\t" +str(float(E_StuffKulcha.get())*40)+"\n")
    if CholeRice.get()>0:
        txtReceipt.insert(END,'CholeRice: \t\t\t'+ E_CholeRice.get() +"\t\t" +str(float(E_CholeRice.get())*60)+ "\n")
    if thali.get()>0:
        txtReceipt.insert(END,'thali: \t\t\t'+ E_thali.get() + "\t\t" +str(float(E_thali.get())*90)+ "\n")
    if RajmaRice.get()>0:
        txtReceipt.insert(END,'RajmaRice: \t\t\t'+ E_RajmaRice.get() +"\t\t" +str(float(E_RajmaRice.get())*60)+  "\n")
    if Dosa.get()>0:
        txtReceipt.insert(END,'Dosa: \t\t\t'+ E_Dosa.get() + "\t\t" +str(float(E_Dosa.get())*70)+ "\n")
    if CholeBhature.get()>0:
        txtReceipt.insert(END,'CholeBhature: \t\t\t'+ E_CholeBhature.get() +"\t\t" +str(float(E_CholeBhature.get())*50)+ "\n")
    if Omelette.get()>0:
        txtReceipt.insert(END,'Omelette: \t\t\t'+ E_Omelette.get() +"\t\t" +str(float(E_Omelette.get())*40)+  "\n")
    if IceCream.get()>0:
        txtReceipt.insert(END,'IceCream: \t\t\t'+ E_IceCream.get() +"\t\t" +str(float(E_IceCream.get())*15)+  "\n")
    if Pastry.get()>0:
        txtReceipt.insert(END,'Pastry: \t\t\t'+ E_Pastry.get() + "\t\t" +str(float(E_Pastry.get())*25)+ "\n")
    if Shake.get()>0:
        txtReceipt.insert(END,'Shake: \t\t\t' + E_Shake.get() + "\t\t" +str(float(E_Shake.get())*40)+ "\n")
    if GulabJamun.get()>0:
        txtReceipt.insert(END,'GulabJamun: \t\t\t'+ E_GulabJamun.get() + "\t\t" +str(float(E_GulabJamun.get())*20)+ "\n")
    if Rasgulla.get()>0:
        txtReceipt.insert(END,'Rasgulla: \t\t\t'+ E_Rasgulla.get()+"\t\t" +str(float(E_Rasgulla.get())*20)+  "\n")
    if ChocoLavaCake.get()>0:
        txtReceipt.insert(END,'ChocoLavaCake: \t\t\t'+E_ChocoLavaCake.get() + "\t\t" +str(float(E_ChocoLavaCake.get())*50)+ "\n")
    txtReceipt.insert(END,"\nTotal amount to be paid: \t\t\t\t INR: " +CostofItem() )
    lis=[Receipt_Ref.get(),DateofOrder.get(),E_ColdDrink.get(),E_ColdCoffee.get(),E_Tea.get(),E_Coffee.get(),E_MinuteMaid.get(),E_IceTea.get(),\
        E_Pizza.get(),E_Patties.get(),E_Samosa.get(),E_Sandwhich.get(),E_Frenchfries.get(),E_StuffKulcha.get(),\
        E_CholeRice.get(),E_thali.get(),E_RajmaRice.get(),E_Dosa.get(),E_CholeBhature.get(),E_Omelette.get(),\
        E_IceCream.get(),E_Pastry.get(),E_Shake.get(),E_GulabJamun.get(),E_Rasgulla.get(),E_ChocoLavaCake.get()]
    return lis

    
    

def Print():
    q=txtReceipt.get("1.0","end-1c")
    filename=tempfile.mktemp(".txt")
    open(filename,"w").write(q)
    os.startfile(filename,"print")
    lis=Receipt()
    tup=tuple(lis)
    mydb=mysql.connector.connect(host="localhost",user="root",passwd="bharat")
    mycursor=mydb.cursor()
    mycursor.execute("use CAFEMANAGEMENT")
    mycursor.execute('INSERT INTO orders(Receipt_Ref,DateofOrder,ColdDrink,ColdCoffee,Tea,Coffee,MinuteMaid,IceTea,Pizza,Patties,Samosa,Sandwhich,Frenchfries,StuffKulcha,CholeRice,thali,RajmaRice,Dosa,CholeBhature,Omelette,IceCream,Pastry,Shake,GulabJamun,Rasgulla,ChocoLavaCake) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)', tup)  
    mydb.commit()
    mydb.close()
    
    
#---------------------Buttons-------------------------------

btnPrint=Button(fb2, padx=16, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), width=5,text="Print",command=Print).grid(row=0, column=0)
btnReceipt=Button(fb2, padx=16, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), width=5,text="Receipt",command=Receipt).grid(row=0, column=1)
btnReset=Button(fb2, padx=16, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), width=5,text="Reset",command=Reset).grid(row=0, column=2)
btnExit=Button(fb2, padx=16, pady=1, bd=4, fg="black", font=('arial', 16, 'bold'), width=5,text="Exit",command=qExit).grid(row=0, column=3)



root.mainloop()
